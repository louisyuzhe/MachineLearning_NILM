# %% [markdown]
# # Importing data and Synchronizing

# %% [markdown]
# ### testing with sample(part of the original data)

# %%
import glob
import pandas as pd

path =r'/home/louis/Desktop/Energy (copy)/' # Path to dataset
allFiles = glob.glob(path + "/*.dat") #Data file name
appliances = ['Kettle', 'Microwave', 'Laptop', 'TV'] #Array of appliances
i = 0 #Counter for appliances array

#Initialize the frame with timestamp (TS) as Index column
frame1 = pd.DataFrame(columns=['TS']) 

#Loop to load dataset into a single frame
for file_ in allFiles:
    df = pd.read_csv(file_,delimiter = ' ', names = ['TS', file_[34:43]])#appliances[i]])
    #df = pd.read_csv(file_,delimiter = ' ', names = ['TS',appliances[i]])
    #frame1 = df.join(df.set_index('TS'), on='TS')
    frame1 = frame1.merge(df, on='TS', how='outer', sort=True) 
    i = i+1
    
#print(frame1['TS'][0])b
#print(len(frame1['TS']))
end = int(frame1['TS'][len(frame1['TS'])-1])
start = int(frame1['TS'][0])
print(frame1)
# Out:
#             TS  channel_1  channel_6  channel_8  channel_5
# 0   1352500098       10.0        1.0        1.0      100.0
# 1   1352500104       20.0        2.0        2.0      200.0
# 2   1352500110       30.0        3.0        3.0        NaN
# 3   1352500114        NaN        NaN        NaN      300.0
# 4   1352500116        NaN        4.0        0.0      400.0
# 5   1352500118       40.0        NaN        NaN        NaN
# 6   1352500122        0.0        5.0        0.0      500.0
# 7   1352500128        0.0        6.0        0.0      600.0
# 8   1352500134        0.0        7.0        0.0        NaN
# 9   1352500140        NaN        8.0        0.0        NaN
# 10  1352500142        0.0        NaN        NaN        NaN
# 11  1352500146       80.0        9.0        9.0        NaN

# %%
#Try formalizing freq to 6 but failed
import numpy as np
print(start)
print(end)
l = [i for i in np.arange(start,end+6,6)]
print(l)
# Out:
# 1352500098
# 1352500146
# [1352500098, 1352500104, 1352500110, 1352500116, 1352500122, 1352500128, 1352500134, 1352500140, 1352500146]

# %%
frame1.set_index([pd.Index(l)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-6eeca7ce53eb> in <module>
# ----> 1 frame1.set_index([pd.Index(l)])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4196         index._cleanup()
#    4197
# -> 4198         frame.index = index
#    4199
#    4200         if not inplace:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 9 elements

# %%
#frameIn = pd.interval_range(start=(frame1['TS'][0]), end = (frame1['TS'][len(frame1['TS'])-1]), freq=4)
#series = pd.Series(range(9), index=index)
date_index2 = pd.date_range(frame1['TS'][1], freq='S')
frame2 = frame1.reindex(date_index2)
#frame1.reindex(frameIn)
print(frame2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-af3a5998bdc8> in <module>
#       1 #frameIn = pd.interval_range(start=(frame1['TS'][0]), end = (frame1['TS'][len(frame1['TS'])-1]), freq=4)
#       2 #series = pd.Series(range(9), index=index)
# ----> 3 date_index2 = pd.date_range(frame1['TS'][1], freq='S')
#       4 frame2 = frame1.reindex(date_index2)
#       5 #frame1.reindex(frameIn)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    1522         start=start, end=end, periods=periods,
#    1523         freq=freq, tz=tz, normalize=normalize,
# -> 1524         closed=closed, **kwargs)
#    1525     return DatetimeIndex._simple_new(
#    1526         dtarr, tz=dtarr.tz, freq=dtarr.freq, name=name)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, closed)
#     404
#     405         if com.count_not_none(start, end, periods, freq) != 3:
# --> 406             raise ValueError('Of the four parameters: start, end, periods, '
#     407                              'and freq, exactly three must be specified')
#     408         freq = to_offset(freq)
#
# ValueError: Of the four parameters: start, end, periods, and freq, exactly three must be specified

# %% [markdown]
# ### Front-filling

# %%
frame1.fillna(method='ffill')
# Out:
#             TS  Kettle  Microwave  Laptop     TV
# 0   1352500098    10.0        1.0     1.0  100.0
# 1   1352500104    20.0        2.0     2.0  200.0
# 2   1352500110    30.0        3.0     3.0  200.0
# 3   1352500114    30.0        3.0     3.0  300.0
# 4   1352500116    30.0        4.0     0.0  400.0
# 5   1352500118    40.0        4.0     0.0  400.0
# 6   1352500122     0.0        5.0     0.0  500.0
# 7   1352500128     0.0        6.0     0.0  600.0
# 8   1352500134     0.0        7.0     0.0  600.0
# 9   1352500140     0.0        8.0     0.0  600.0
# 10  1352500142     0.0        8.0     0.0  600.0
# 11  1352500146    80.0        9.0     9.0  600.0

# %% [markdown]
# ### Zero-filling

# %%
frame1.fillna(0)
# Out:
#             TS  Kettle  Microwave  Laptop     TV
# 0   1352500098    10.0        1.0     1.0  100.0
# 1   1352500104    20.0        2.0     2.0  200.0
# 2   1352500110    30.0        3.0     3.0    0.0
# 3   1352500114     0.0        0.0     0.0  300.0
# 4   1352500116     0.0        4.0     0.0  400.0
# 5   1352500118    40.0        0.0     0.0    0.0
# 6   1352500122     0.0        5.0     0.0  500.0
# 7   1352500128     0.0        6.0     0.0  600.0
# 8   1352500134     0.0        7.0     0.0    0.0
# 9   1352500140     0.0        8.0     0.0    0.0
# 10  1352500142     0.0        0.0     0.0    0.0
# 11  1352500146    80.0        9.0     9.0    0.0

# %% [markdown]
# ## Actual Data

# %%
import glob
import pandas as pd

path =r'/home/louis/Desktop/Energy/' # Path to dataset
allFiles = glob.glob(path + "/*.dat") #Data file name
appliances = ['Kettle', 'Microwave', 'Laptop', 'TV'] #Array of appliances
i = 0 #Counter for appliances array

#Initialize the frame with timestamp (TS) as Index column
frame1 = pd.DataFrame(columns=['TS']) 

#Loop to load dataset into a single frame
for file_ in allFiles:
    df = pd.read_csv(file_,delimiter = ' ', names = ['TS', file_[34:43]])
    frame1 = frame1.merge(df, on='TS', how='outer', sort =True) 
    i = i+1
    
print(frame1)
